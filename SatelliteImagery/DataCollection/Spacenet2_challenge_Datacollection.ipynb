# %% [markdown]
# <a href="https://colab.research.google.com/github/snvssk/data298A/blob/saidev/Spacenet2_BuildingDetection_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install radiant_mlhub
# Out:
# ...
#      |████████████████████████████████| 137 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 590 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
# !mlhub configure
# Out:
# API Key: 446a82b050407845be35c17ac33fde3d74ffdac28dbf3d5fde18c6c9f0fbc134
# Wrote profile to /root/.mlhub/profiles

# %%
from radiant_mlhub import Dataset
ds = Dataset.fetch('spacenet2')
for c in ds.collections:
    print(c.id)
# Out:
# sn2_AOI_2_Vegas
# sn2_AOI_3_Paris
# sn2_AOI_4_Shanghai
# sn2_AOI_5_Khartoum

# %%
ds.collections.source_imagery
# Out:
# [<Collection id=sn2_AOI_2_Vegas>,
#  <Collection id=sn2_AOI_3_Paris>,
#  <Collection id=sn2_AOI_4_Shanghai>,
#  <Collection id=sn2_AOI_5_Khartoum>]

# %%
Vegas_data = ds.collections.source_imagery[0] 
Paris_data = ds.collections.source_imagery[1] 
Shanghai_data = ds.collections.source_imagery[2]
Khartoum_data = ds.collections.source_imagery[3]

# %%
from pprint import pprint
pprint(Vegas_data.to_dict())
# Out:
# {'description': 'SpaceNet 2 Vegas Chipped Training Dataset',
#  'extent': {'spatial': {'bbox': [[-115.3075176,
#                                   36.1212776997,
#                                   -115.1513226,
#                                   36.2616777]]},
#             'temporal': {'interval': [['2015-10-22T00:00:00Z', None]]}},
#  'id': 'sn2_AOI_2_Vegas',
#  'license': 'CC-BY-SA-4.0',
#  'links': [{'href': 'https://api.radiant.earth/mlhub/v1/collections/sn2_AOI_2_Vegas/items',
#             'rel': 'items',
#             'type': 'application/geo+json'},
#            {'href': 'https://api.radiant.earth/mlhub/v1/',
#             'rel': 'parent',
#             'type': 'application/json'},
#            {'href': 'https://api.radiant.earth/mlhub/v1/',
#             'rel': <RelType.ROOT: 'root'>,
#             'title': 'Radiant MLHub API',
#             'type': <MediaType.JSON: 'application/json'>},
# ...

# %%
Paris_data.download('spacenet2/')
# Out:
#   0%|          | 0/5727.5 [00:00<?, ?M/s]
# PosixPath('/content/spacenet2/sn2_AOI_3_Paris.tar.gz')

# %%
Shanghai_data.download('spacenet2/')
Khartoum_data.download('spacenet2/')
Vegas_data.download('spacenet2/')
# Out:
#   0%|          | 0/25105.7 [00:00<?, ?M/s]
#   0%|          | 0/5069.6 [00:00<?, ?M/s]
#   0%|          | 0/25624.0 [00:00<?, ?M/s]
# PosixPath('/content/spacenet2/sn2_AOI_2_Vegas.tar.gz')

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'data298-347103'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://radiant_mlhub/

# %%
bucket_name = 'radiant_mlhub'
path = "spacenet2"
# !gsutil -m cp -r /content/spacenet2/* gs://{bucket_name}/{path}
# Out:
# Copying file:///content/spacenet2/sn2_AOI_4_Shanghai.tar.gz [Content-Type=application/x-tar]...
# Copying file:///content/spacenet2/sn2_AOI_5_Khartoum.tar.gz [Content-Type=application/x-tar]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file:///content/spacenet2/sn2_AOI_2_Vegas.tar.gz [Content-Type=application/x-tar]...
# ...

# %%
# !tar -zxvf /content/spacenet2/sn2_AOI_5_Khartoum.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img1623-labels/stac.json
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img1434-labels/
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img1434-labels/label.geojson
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img1434-labels/stac.json
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img361/
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img361/PS-MS.tif
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img361/PAN.tif
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img361/MS.tif
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img361/PS-RGB.tif
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img361/stac.json
# sn2_AOI_5_Khartoum/sn2_SN2_buildings_train_AOI_5_Khartoum_PS-RGB_img133-labels/
# ...
