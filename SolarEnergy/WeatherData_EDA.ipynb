# %% [markdown]
# <a href="https://colab.research.google.com/github/snvssk/data298A/blob/saidev/SolarEnergy/WeatherData_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EDA

# %%
import pandas as pd
df = pd.read_csv('/content/all_cities_transformed_combined.csv')
df
# Out:
#         Unnamed: 0    Year  Month   Day  Hour  Minute  Temperature  \
# 0                0  2018.0    1.0   1.0   0.0     0.0         11.2
# 1                1  2018.0    1.0   1.0   0.0    30.0         11.2
# 2                2  2018.0    1.0   1.0   1.0     0.0         11.1
# 3                3  2018.0    1.0   1.0   1.0    30.0         11.0
# 4                4  2018.0    1.0   1.0   2.0     0.0         10.9
# ...            ...     ...    ...   ...   ...     ...          ...
# 946181      946181  2013.0   12.0  31.0  21.0    30.0          6.0
# 946182      946182  2013.0   12.0  31.0  22.0     0.0          6.0
# 946183      946183  2013.0   12.0  31.0  22.0    30.0          5.0
# 946184      946184  2013.0   12.0  31.0  23.0     0.0          4.0
# 946185      946185  2013.0   12.0  31.0  23.0    30.0          4.0
#
#         Cloud_Type  Dew_Point  GHI  Relative_Humidity  Solar_Zenith_Angle  \
# 0              4.0       10.2  0.0              93.63              165.41
# 1              4.0       10.2  0.0              93.63              165.11
# 2              4.0       10.1  0.0              93.38              162.29
# 3              0.0       10.1  0.0              94.00              157.91
# 4              0.0        9.9  0.0              93.32              152.72
# ...            ...        ...  ...                ...                 ...
# 946181         1.0        0.0  0.0              74.05              142.58
# 946182         1.0        0.0  0.0              74.40              148.35
# 946183         0.0        0.0  0.0              79.80              153.89
# 946184         0.0        0.0  0.0              80.32              158.95
# 946185         0.0        0.0  0.0              86.20              163.08
#
#         Surface_Albedo  Pressure  Precipitable_Water  Wind_Direction  \
# 0                0.100    1024.0               1.700           294.0
# 1                0.100    1024.0               1.700           307.0
# 2                0.100    1024.0               1.700           321.0
# 3                0.100    1024.0               1.800           332.0
# 4                0.100    1024.0               1.800           344.0
# ...                ...       ...                 ...             ...
# 946181           0.113    1020.0               0.950           174.5
# 946182           0.113    1020.0               0.977           152.1
# 946183           0.113    1020.0               0.972           152.1
# 946184           0.113    1020.0               0.968           166.7
# 946185           0.113    1020.0               0.980           166.7
#
#         Wind_Speed  Location
# 0              0.7  117987.0
# 1              0.7  117987.0
# 2              0.7  117987.0
# 3              0.7  117987.0
# 4              0.7  117987.0
# ...            ...       ...
# 946181         0.6  117546.0
# 946182         0.9  117546.0
# 946183         1.1  117546.0
# 946184         1.3  117546.0
# 946185         1.3  117546.0
#
# [946186 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'Temperature',
#        'Cloud_Type', 'Dew_Point', 'GHI', 'Relative_Humidity',
#        'Solar_Zenith_Angle', 'Surface_Albedo', 'Pressure',
#        'Precipitable_Water', 'Wind_Direction', 'Wind_Speed', 'Location'],
#       dtype='object')

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
null_rows = df[df.isna().any(axis=1)]
null_rows
# Out:
#         Year     Month  Day  Hour  Minute  Temperature  Cloud_Type  Dew_Point  \
# 17520    NaN  117987.0  NaN   NaN     NaN        37.37        -8.0        NaN
# 17521    NaN       NaN  NaN   NaN     NaN          NaN         NaN        NaN
# 35042    NaN  117987.0  NaN   NaN     NaN        37.37        -8.0        NaN
# 35043    NaN       NaN  NaN   NaN     NaN          NaN         NaN        NaN
# 52564    NaN  117987.0  NaN   NaN     NaN        37.37        -8.0        NaN
# ...      ...       ...  ...   ...     ...          ...         ...        ...
# 893621   NaN       NaN  NaN   NaN     NaN          NaN         NaN        NaN
# 911142   NaN  117546.0  NaN   NaN     NaN        37.33        -8.0        NaN
# 911143   NaN       NaN  NaN   NaN     NaN          NaN         NaN        NaN
# 928664   NaN  117546.0  NaN   NaN     NaN        37.33        -8.0        NaN
# 928665   NaN       NaN  NaN   NaN     NaN          NaN         NaN        NaN
#
#         GHI  Relative_Humidity  Solar_Zenith_Angle  Surface_Albedo  Pressure  \
# 17520   NaN                NaN                 NaN             NaN       NaN
# 17521   NaN                NaN                 NaN             NaN       NaN
# 35042   NaN                NaN                 NaN             NaN       NaN
# 35043   NaN                NaN                 NaN             NaN       NaN
# 52564   NaN                NaN                 NaN             NaN       NaN
# ...     ...                ...                 ...             ...       ...
# 893621  NaN                NaN                 NaN             NaN       NaN
# 911142  NaN                NaN                 NaN             NaN       NaN
# 911143  NaN                NaN                 NaN             NaN       NaN
# 928664  NaN                NaN                 NaN             NaN       NaN
# 928665  NaN                NaN                 NaN             NaN       NaN
#
#         Precipitable_Water  Wind_Direction  Wind_Speed  Location
# 17520                  NaN             NaN         NaN  117987.0
# 17521                  NaN             NaN         NaN  117987.0
# 35042                  NaN             NaN         NaN  117987.0
# 35043                  NaN             NaN         NaN  117987.0
# 52564                  NaN             NaN         NaN  117987.0
# ...                    ...             ...         ...       ...
# 893621                 NaN             NaN         NaN  117546.0
# 911142                 NaN             NaN         NaN  117546.0
# 911143                 NaN             NaN         NaN  117546.0
# 928664                 NaN             NaN         NaN  117546.0
# 928665                 NaN             NaN         NaN  117546.0
#
# [106 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# Year                  106
# Month                  53
# Day                   106
# Hour                  106
# Minute                106
# Temperature            53
# Cloud_Type             53
# Dew_Point             106
# GHI                   106
# Relative_Humidity     106
# Solar_Zenith_Angle    106
# Surface_Albedo        106
# Pressure              106
# Precipitable_Water    106
# Wind_Direction        106
# Wind_Speed            106
# Location               10
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Hour                  0
# Minute                0
# Temperature           0
# Cloud_Type            0
# Dew_Point             0
# GHI                   0
# Relative_Humidity     0
# Solar_Zenith_Angle    0
# Surface_Albedo        0
# Pressure              0
# Precipitable_Water    0
# Wind_Direction        0
# Wind_Speed            0
# Location              0
# dtype: int64

# %%
#df.head

# %%
target = df['GHI']

# %%
target.describe()
# Out:
# count    946080.000000
# mean        217.074941
# std         304.695853
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         408.000000
# max        1055.000000
# Name: GHI, dtype: float64

# %%
features = df.drop('GHI', axis = 1)

# %%
#features.head

# %%
print("Features Shape",features.shape)
print("Target Shape",target.shape)
# Out:
# Features Shape (946080, 16)
# Target Shape (946080,)

# %% [markdown]
# ## Correlation

# %%
import matplotlib.pyplot as plt

def show_scatter_plot(title, 
                      x_label, y_label, 
                      x_values, y_values):
    """
    @param title the chart title.
    @param x_label the x-axis label.
    @param y_label the y-axis label.
    @param x_values the independent x values to plot.
    @param y_values the dependent y values to plot.
    """
    plt.scatter(x_values, y_values)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

# %%
import math
import numpy as np

def calculate_r(x_values, y_values):
    """
    Calculate the correlation coefficient.
    @param x_values the x values.
    @param y_values the y values.
    @return the correlation coefficient.
    """
    x = np.array(x_values)
    y = np.array(y_values)
    
    n = len(x)
    sum_x  = np.sum(x)
    sum_y  = np.sum(y)
    sum_xx = np.sum(x*x)
    sum_yy = np.sum(y*y)
    sum_xy = np.sum(x*y)
    
    numerator = sum_xy - (sum_x*sum_y)/n
    denominator = math.sqrt(sum_xx - (sum_x*sum_x)/n)*math.sqrt(sum_yy - (sum_y*sum_y)/n)
    
    r = (numerator/denominator) * 100
    return r

# %%
r = calculate_r(df["Solar_Zenith_Angle"], target)
print("Correlation between GHI and Solar Zenith Angle", f'R2 = {r:.3f}')
# Out:
# Correlation between GHI and Solar Zenith Angle R2 = -84.382

# %%
r = calculate_r(df["Temperature"], target)
print("Correlation between GHI and Temperature", f'R2 = {r:.3f}')
# Out:
# Correlation between GHI and Temperature R2 = 69.844

# %%
r = calculate_r(df["Pressure"], target)
print("Correlation between GHI and Pressure", f'R2 = {r:.3f}')
# Out:
# Correlation between GHI and Pressure R2 = -3.829

# %%
show_scatter_plot('Scatterplot','Temperature','GHI',df["Temperature"],target)

# %%
show_scatter_plot('Scatterplot','Solar Zenith Angle','GHI',df["Solar_Zenith_Angle"],target)

# %%
show_scatter_plot('Scatterplot','Dew Point','GHI',df["Dew_Point"],target)

# %%
df.corr(method ='pearson')
#correlation = df["GHI"].corr(df["Temperature"])
#correlation 
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None, low=0.75, high=1.0)
# Out:
# <style type="text/css">
# #T_5a29a_row0_col0, #T_5a29a_row1_col1, #T_5a29a_row2_col2, #T_5a29a_row3_col3, #T_5a29a_row4_col4, #T_5a29a_row5_col5, #T_5a29a_row6_col6, #T_5a29a_row7_col7, #T_5a29a_row8_col8, #T_5a29a_row9_col9, #T_5a29a_row10_col10, #T_5a29a_row11_col11, #T_5a29a_row12_col12, #T_5a29a_row13_col13, #T_5a29a_row14_col14, #T_5a29a_row15_col15, #T_5a29a_row16_col16 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_5a29a_row0_col1, #T_5a29a_row0_col2, #T_5a29a_row0_col3, #T_5a29a_row0_col4, #T_5a29a_row0_col10, #T_5a29a_row0_col16, #T_5a29a_row1_col0, #T_5a29a_row1_col3, #T_5a29a_row1_col4, #T_5a29a_row1_col14, #T_5a29a_row1_col16, #T_5a29a_row2_col0, #T_5a29a_row2_col3, #T_5a29a_row2_col4, #T_5a29a_row2_col5, #T_5a29a_row2_col8, #T_5a29a_row2_col10, #T_5a29a_row2_col11, #T_5a29a_row2_col13, #T_5a29a
{
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_5a29a_row6_col14, #T_5a29a_row14_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5a29a_row7_col9, #T_5a29a_row9_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_5a29a_row7_col13, #T_5a29a_row12_col16, #T_5a29a_row13_col7, #T_5a29a_row16_col12 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_5a29a_row7_col14, #T_5a29a_row14_col7, #T_5a29a_row14_col15, #T_5a29a_row15_col14 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_5a29a_row8_col10, #T_5a29a_row10_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5a29a_row8_col14, #T_5a29a_row9_col13, #T_5a29a_row13_col9, #T_5a29a_row13_col15, #T_5a29a_row14_col8, #T_5a29a_row15_col13 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5a29a_row9_col10, #T_5a29a_row10_col9 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_5a29a_row9_col15, #T_5a29a_row15_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_5a29a_row10_col15, #T_5a29a_row15_col10 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_5a29a_row11_col12, #T_5a29a_row12_col11 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_5a29a_row11_col15, #T_5a29a_row15_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_5a29a_row11_col16, #T_5a29a_row16_col11 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_5a29a_row12_col13, #T_5a29a_row13_col12 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# </style>
# <table id="T_5a29a_" class="dataframe">
#   <thead>

# %% [markdown]
# # PCA

# %%
feature1 = features.drop(['Cloud_Type','Wind_Speed','Wind_Direction','Surface_Albedo'], axis = 1)

# %%
#feature1.head

# %%
# initializing the pca
from sklearn import decomposition
pca = decomposition.PCA()

# %%
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler().fit_transform(features)
print(standardized_data.shape)
sample_data = standardized_data
# Out:
# (946080, 16)

# %%
# PCA for dimensionality redcution (non-visualization)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pca.n_components = 14
pca_data = pca.fit_transform(sample_data)

percentage_var_explained = pca.explained_variance_ / np.sum(pca.explained_variance_);

cum_var_explained = np.cumsum(percentage_var_explained)

# Plot the PCA spectrum
plt.figure(1, figsize=(6, 4))

plt.clf()
plt.plot(cum_var_explained, linewidth=2)
plt.axis('tight')
plt.grid()
plt.xlabel('n_components')
plt.ylabel('Cumulative_explained_variance')
plt.show()

# If we take 11-dimensions, approx. 97% of variance is expalined.

# %% [markdown]
# # Ranbdom Forest for feature selection

# %%
#https://www.yourdatateacher.com/2021/10/11/feature-selection-with-random-forest/#:~:text=Random%20Forest%20is%20a%20very,a%20Recursive%20Feature%20Elimination%20procedure.
import numpy as np
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV
import matplotlib.pyplot as plt

# %%
X_train, X_test, y_train, y_test = train_test_split(standardized_data , target, test_size=0.33, random_state=42)

# %%
print("x_train shape",X_train.shape)
print("x_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_text shape",y_test.shape)
# Out:
# x_train shape (633873, 16)
# x_test shape (312207, 16)
# y_train shape (633873,)
# y_text shape (312207,)

# %%
rf = RandomForestRegressor(random_state=0)

rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
f_i = list(zip(features,rf.feature_importances_))
f_i.sort(key = lambda x : x[1])
plt.barh([x[0] for x in f_i],[x[1] for x in f_i])

plt.show()

# %%
#All feature
rfe = RFECV(rf,cv=5,scoring="neg_mean_squared_error")
rfe.fit(X_train,y_train)
# Out:
# 'rfe = RFECV(rf,cv=5,scoring="neg_mean_squared_error")\nrfe.fit(X_train,y_train)'

# %%
selected_features = np.array(features)[rfe.get_support()]

# %% [markdown]
# # XGBoost

# %%
from datetime import datetime

# %%
df = pd.read_csv('/content/all_cities_transformed_combined.csv')
df
# Out:
#         Unnamed: 0    Year  Month   Day  Hour  Minute  Temperature  \
# 0                0  2018.0    1.0   1.0   0.0     0.0         11.2
# 1                1  2018.0    1.0   1.0   0.0    30.0         11.2
# 2                2  2018.0    1.0   1.0   1.0     0.0         11.1
# 3                3  2018.0    1.0   1.0   1.0    30.0         11.0
# 4                4  2018.0    1.0   1.0   2.0     0.0         10.9
# ...            ...     ...    ...   ...   ...     ...          ...
# 946181      946181  2013.0   12.0  31.0  21.0    30.0          6.0
# 946182      946182  2013.0   12.0  31.0  22.0     0.0          6.0
# 946183      946183  2013.0   12.0  31.0  22.0    30.0          5.0
# 946184      946184  2013.0   12.0  31.0  23.0     0.0          4.0
# 946185      946185  2013.0   12.0  31.0  23.0    30.0          4.0
#
#         Cloud_Type  Dew_Point  GHI  Relative_Humidity  Solar_Zenith_Angle  \
# 0              4.0       10.2  0.0              93.63              165.41
# 1              4.0       10.2  0.0              93.63              165.11
# 2              4.0       10.1  0.0              93.38              162.29
# 3              0.0       10.1  0.0              94.00              157.91
# 4              0.0        9.9  0.0              93.32              152.72
# ...            ...        ...  ...                ...                 ...
# 946181         1.0        0.0  0.0              74.05              142.58
# 946182         1.0        0.0  0.0              74.40              148.35
# 946183         0.0        0.0  0.0              79.80              153.89
# 946184         0.0        0.0  0.0              80.32              158.95
# 946185         0.0        0.0  0.0              86.20              163.08
#
#         Surface_Albedo  Pressure  Precipitable_Water  Wind_Direction  \
# 0                0.100    1024.0               1.700           294.0
# 1                0.100    1024.0               1.700           307.0
# 2                0.100    1024.0               1.700           321.0
# 3                0.100    1024.0               1.800           332.0
# 4                0.100    1024.0               1.800           344.0
# ...                ...       ...                 ...             ...
# 946181           0.113    1020.0               0.950           174.5
# 946182           0.113    1020.0               0.977           152.1
# 946183           0.113    1020.0               0.972           152.1
# 946184           0.113    1020.0               0.968           166.7
# 946185           0.113    1020.0               0.980           166.7
#
#         Wind_Speed  Location
# 0              0.7  117987.0
# 1              0.7  117987.0
# 2              0.7  117987.0
# 3              0.7  117987.0
# 4              0.7  117987.0
# ...            ...       ...
# 946181         0.6  117546.0
# 946182         0.9  117546.0
# 946183         1.1  117546.0
# 946184         1.3  117546.0
# 946185         1.3  117546.0
#
# [946186 rows x 18 columns]

# %%
df1 = df.drop(['Year', 'Month', 'Day','Hour','Minute'], axis = 1)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Temperature', 'Cloud_Type', 'Dew_Point', 'GHI',
#        'Relative_Humidity', 'Solar_Zenith_Angle', 'Surface_Albedo', 'Pressure',
#        'Precipitable_Water', 'Wind_Direction', 'Wind_Speed', 'Location'],
#       dtype='object')

# %%
df1 = df1.drop("Unnamed: 0", axis = 1)

# %%
df1.head()
# Out:
#    Temperature  Cloud_Type  Dew_Point  GHI  Relative_Humidity  \
# 0         11.2         4.0       10.2  0.0              93.63
# 1         11.2         4.0       10.2  0.0              93.63
# 2         11.1         4.0       10.1  0.0              93.38
# 3         11.0         0.0       10.1  0.0              94.00
# 4         10.9         0.0        9.9  0.0              93.32
#
#    Solar_Zenith_Angle  Surface_Albedo  Pressure  Precipitable_Water  \
# 0              165.41             0.1    1024.0                 1.7
# 1              165.11             0.1    1024.0                 1.7
# 2              162.29             0.1    1024.0                 1.7
# 3              157.91             0.1    1024.0                 1.8
# 4              152.72             0.1    1024.0                 1.8
#
#    Wind_Direction  Wind_Speed  Location
# 0           294.0         0.7  117987.0
# 1           307.0         0.7  117987.0
# 2           321.0         0.7  117987.0
# 3           332.0         0.7  117987.0
# 4           344.0         0.7  117987.0

# %%
df1['Datetime'] = pd.to_datetime(df1['Datetime'])

# %%
#https://towardsdatascience.com/time-series-analysis-using-pandas-in-python-f726d87a97d8
df1.dtypes
# Out:
# Datetime              datetime64[ns]
# GHI                            int64
# Cloud Type                     int64
# Dew Point                    float64
# Solar Zenith Angle           float64
# Surface Albedo               float64
# Wind Speed                   float64
# Precipitable Water           float64
# Wind Direction                 int64
# Relative Humidity            float64
# Temperature                  float64
# Pressure                       int64
# dtype: object

# %%
data = df1.set_index('Datetime')
data
# Out:
#                      GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# Datetime
# 2020-01-01 00:00:00    0           7        8.4              165.52
# 2020-01-01 00:30:00    0           7        8.8              165.13
# 2020-01-01 01:00:00    0           7        9.1              162.24
# 2020-01-01 01:30:00    0           7        9.1              157.81
# 2020-01-01 02:00:00    0           7        9.2              152.59
# ...                  ...         ...        ...                 ...
# 2020-12-31 21:30:00    0           7        6.4              142.77
# 2020-12-31 22:00:00    0           7        6.8              148.54
# 2020-12-31 22:30:00    0           7        6.8              154.08
# 2020-12-31 23:00:00    0           7        7.8              159.13
# 2020-12-31 23:30:00    0           7        7.8              163.23
#
#                      Surface Albedo  Wind Speed  Precipitable Water  \
# Datetime
# 2020-01-01 00:00:00            0.13         1.2                 1.1
# 2020-01-01 00:30:00            0.13         1.0                 1.1
# 2020-01-01 01:00:00            0.13         0.9                 1.2
# 2020-01-01 01:30:00            0.13         0.8                 1.2
# 2020-01-01 02:00:00            0.13         0.8                 1.2
# ...                             ...         ...                 ...
# 2020-12-31 21:30:00            0.13         1.0                 1.0
# 2020-12-31 22:00:00            0.13         1.2                 1.0
# 2020-12-31 22:30:00            0.13         1.3                 1.0
# 2020-12-31 23:00:00            0.13         1.3                 1.1
# 2020-12-31 23:30:00            0.13         1.3                 1.1
#
#                      Wind Direction  Relative Humidity  Temperature  Pressure
# Datetime
# 2020-01-01 00:00:00             282             100.00          8.4      1024
# 2020-01-01 00:30:00             278              99.82          8.8      1024
# 2020-01-01 01:00:00             274             100.00          9.1      1024
# 2020-01-01 01:30:00             265             100.00          9.1      1024
# 2020-01-01 02:00:00             256             100.00          9.2      1024
# ...                             ...                ...          ...       ...
# 2020-12-31 21:30:00             235              77.71         10.1      1024
# 2020-12-31 22:00:00             251              84.03          9.4      1024
# 2020-12-31 22:30:00             260              86.90          8.9      1024
# 2020-12-31 23:00:00             269              96.71          8.3      1024
# 2020-12-31 23:30:00             275              96.06          8.4      1024
#
# [17568 rows x 11 columns]

# %%
data.index
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:30:00',
#                '2020-01-01 01:00:00', '2020-01-01 01:30:00',
#                '2020-01-01 02:00:00', '2020-01-01 02:30:00',
#                '2020-01-01 03:00:00', '2020-01-01 03:30:00',
#                '2020-01-01 04:00:00', '2020-01-01 04:30:00',
#                ...
#                '2020-12-31 19:00:00', '2020-12-31 19:30:00',
#                '2020-12-31 20:00:00', '2020-12-31 20:30:00',
#                '2020-12-31 21:00:00', '2020-12-31 21:30:00',
#                '2020-12-31 22:00:00', '2020-12-31 22:30:00',
#                '2020-12-31 23:00:00', '2020-12-31 23:30:00'],
#               dtype='datetime64[ns]', name='Datetime', length=17568, freq=None)

# %%
#We can set frequency Available frequencies in pandas include hourly (‘H’), 
#calendar daily (‘D’), business daily (‘B’), weekly (‘W’), monthly (‘M’), 
#quarterly (‘Q’), annual (‘A’), and many others
data_freq = data.asfreq('D')
data_freq
# Out:
#             GHI  Cloud Type  Dew Point  Solar Zenith Angle  Surface Albedo  \
# Datetime
# 2020-01-01    0           7        8.4              165.52            0.13
# 2020-01-02    0           0        9.7              165.42            0.13
# 2020-01-03    0           4        9.5              165.32            0.13
# 2020-01-04    0           7        8.9              165.20            0.13
# 2020-01-05    0           7        7.4              165.08            0.13
# ...         ...         ...        ...                 ...             ...
# 2020-12-27    0           7        7.5              165.85            0.13
# 2020-12-28    0           7        5.6              165.79            0.13
# 2020-12-29    0           0        6.7              165.72            0.13
# 2020-12-30    0           7        5.8              165.64            0.12
# 2020-12-31    0           7       10.3              165.55            0.12
#
#             Wind Speed  Precipitable Water  Wind Direction  Relative Humidity  \
# Datetime
# 2020-01-01         1.2                 1.1             282             100.00
# 2020-01-02         1.3                 1.9             295             100.00
# 2020-01-03         0.5                 1.0              92              89.80
# 2020-01-04         1.5                 1.1             215             100.00
# 2020-01-05         1.2                 1.1             285             100.00
# ...                ...                 ...             ...                ...
# 2020-12-27         1.2                 0.8             329             100.00
# 2020-12-28         1.2                 1.8              82              87.47
# 2020-12-29         1.0                 1.4             324             100.00
# 2020-12-30         1.4                 0.7             268             100.00
# 2020-12-31         2.8                 1.7             275              92.53
#
#             Temperature  Pressure
# Datetime
# 2020-01-01          8.4      1024
# 2020-01-02          9.7      1022
# 2020-01-03         11.1      1024
# 2020-01-04          8.9      1028
# 2020-01-05          7.4      1033
# ...                 ...       ...
# 2020-12-27          7.5      1022
# 2020-12-28          7.5      1008
# 2020-12-29          6.7      1020
# 2020-12-30          5.8      1029
# 2020-12-31         11.5      1025
#
# [366 rows x 11 columns]

# %%
# 2020-11-15            1.358333          69.752560    11.682738    1.363988
# 2020-11-22            1.332143          72.068810    12.830357    1.819048
# 2020-11-29            0.916071          65.492262    11.293452    1.556250
# 2020-12-06            1.171726          67.294881    12.178571    1.167262
# 2020-12-13            1.350298          69.041607    12.322917    1.803571
# 2020-12-20            1.198810          74.567173    10.186012    1.517857
# 2020-12-27            1.063690          77.088036     9.800595    1.682440
# 2021-01-03            1.152604          79.272917     9.816667    1.551563

# %%
data_monthly_max = data[data_columns].resample('M').max() # W stands for weekly
data_monthly_max
# Out:
#              GHI  Dew Point  Solar Zenith Angle  Surface Albedo  \
# Datetime
# 2020-01-31   605       14.3              165.52            0.13
# 2020-02-29   761       13.4              159.80            0.14
# 2020-03-31   883       11.9              149.95            0.14
# 2020-04-30   982       13.6              137.83            0.15
# 2020-05-31  1029       15.3              127.42            0.15
# 2020-06-30  1047       15.0              120.54            0.16
# 2020-07-31  1042       13.2              124.47            0.15
# 2020-08-31   996       15.8              134.22            0.15
# 2020-09-30   871       16.5              145.70            0.15
# 2020-10-31   793       15.3              156.89            0.14
# 2020-11-30   641       14.3              164.39            0.14
# 2020-12-31   537       12.3              166.07            0.13
#
#             Precipitable Water  Relative Humidity  Temperature  Wind Speed
# Datetime
# 2020-01-31                 3.3              100.0         20.6         6.2
# 2020-02-29                 2.2              100.0         25.2         7.3
# 2020-03-31                 2.5              100.0         25.9         5.1
# 2020-04-30                 3.2              100.0         29.1         4.4
# 2020-05-31                 3.4              100.0         36.4         5.4
# 2020-06-30                 3.1              100.0         36.6         5.8
# 2020-07-31                 2.7              100.0         34.6         5.0
# 2020-08-31                 4.6              100.0         41.6         4.7
# 2020-09-30                 3.4              100.0         44.0         4.4
# 2020-10-31                 3.8              100.0         37.1         5.0
# 2020-11-30                 3.4              100.0         31.9         5.6
# 2020-12-31                 3.3              100.0         23.0         4.8

# %%
#To compute a 7-day rolling mean
#center = True means for the time bin, say Jan 1 to Jan 8, the rolling mean would be 
#calculated and placed next to the center of the bin i.e. Jan 4. To make it clearer
data_7d_rol = data[data_columns].rolling(window = 7, center = True).mean()
data_7d_rol
# Out:
#                      GHI  Dew Point  Solar Zenith Angle  Surface Albedo  \
# Datetime
# 2020-01-01 00:00:00  NaN        NaN                 NaN             NaN
# 2020-01-01 00:30:00  NaN        NaN                 NaN             NaN
# 2020-01-01 01:00:00  NaN        NaN                 NaN             NaN
# 2020-01-01 01:30:00  0.0   8.928571          155.915714            0.13
# 2020-01-01 02:00:00  0.0   8.957143          151.588571            0.13
# ...                  ...        ...                 ...             ...
# 2020-12-31 21:30:00  0.0   6.685714          142.467143            0.13
# 2020-12-31 22:00:00  0.0   6.900000          147.934286            0.13
# 2020-12-31 22:30:00  NaN        NaN                 NaN             NaN
# 2020-12-31 23:00:00  NaN        NaN                 NaN             NaN
# 2020-12-31 23:30:00  NaN        NaN                 NaN             NaN
#
#                      Precipitable Water  Relative Humidity  Temperature  \
# Datetime
# 2020-01-01 00:00:00                 NaN                NaN          NaN
# 2020-01-01 00:30:00                 NaN                NaN          NaN
# 2020-01-01 01:00:00                 NaN                NaN          NaN
# 2020-01-01 01:30:00            1.171429          99.974286     8.928571
# 2020-01-01 02:00:00            1.185714          99.974286     8.957143
# ...                                 ...                ...          ...
# 2020-12-31 21:30:00            1.014286          80.172857    10.057143
# 2020-12-31 22:00:00            1.028571          83.937143     9.585714
# 2020-12-31 22:30:00                 NaN                NaN          NaN
# 2020-12-31 23:00:00                 NaN                NaN          NaN
# 2020-12-31 23:30:00                 NaN                NaN          NaN
#
#                      Wind Speed
# Datetime
# 2020-01-01 00:00:00         NaN
# 2020-01-01 00:30:00         NaN
# 2020-01-01 01:00:00         NaN
# 2020-01-01 01:30:00    0.942857
# 2020-01-01 02:00:00    0.928571
# ...                         ...
# 2020-12-31 21:30:00    0.985714
# 2020-12-31 22:00:00    1.085714
# 2020-12-31 22:30:00         NaN
# 2020-12-31 23:00:00         NaN
# 2020-12-31 23:30:00         NaN
#
# [17568 rows x 8 columns]

# %%
data_365d_rol = data[data_columns].rolling(window = 365, center = True).mean()

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize = (11,4))
# plotting daily data
ax.plot(data['GHI'], marker='.', markersize=2, color='0.6',linestyle='None', label='Daily')
# plotting 7-day rolling data
ax.plot(data_7d_rol['GHI'], linewidth=2, label='7-d Rolling Mean')
# plotting annual rolling data
ax.plot(data_365d_rol['GHI'], color='0.2', linewidth=3, label='Trend (365-d Rolling Mean)')
# Beautification of plot
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('GHI (w/m2)')
ax.set_title('Trends in GHI')
# Out:
# Text(0.5, 1.0, 'Trends in GHI')

# %%
plt.figure(figsize=(11,4), dpi= 80)
data['GHI'].plot(linewidth = 0.5)
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
#Weekly Oscilation
data.loc['2020-04': '2020-04','GHI'].plot(marker = 'o', figsize=(11, 9))
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
# Extract the year, month, date separately using the index set
data['Year'] = data.index.year
data['Month'] = data.index.month
data['Weekday_Name'] = data.index.weekday

# %%
import seaborn as sns
fig, axes = plt.subplots(10, 1, figsize=(20, 40), sharex=True)
for name, ax in zip(['GHI','Dew Point', 'Solar Zenith Angle','Surface Albedo','Wind Speed','Precipitable Water','Wind Direction','Relative Humidity','Temperature','Pressure'], axes):
    sns.boxplot(data=data, x='Month', y=name, ax=ax)
    ax.set_ylabel('w/m2')
    ax.set_title(name)
    # Keep the x-axis label for only the bottom subplot
    if ax != axes[-1]:
        ax.set_xlabel('')

# %% [markdown]
# Datetime              datetime64[ns]
# GHI                            int64
# Cloud Type                     int64
# Dew Point                    float64
# Solar Zenith Angle           float64
# Surface Albedo               float64
# Wind Speed                   float64
# Precipitable Water           float64
# Wind Direction                 int64
# Relative Humidity            float64
# Temperature                  float64
# Pressure                       int64
# dtype: object
