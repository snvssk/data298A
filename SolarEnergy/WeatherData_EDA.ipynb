# %% [markdown]
# <a href="https://colab.research.google.com/github/snvssk/data298A/blob/development/SolarEnergy/WeatherData_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EDA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/Shareddrives/DATA240 Team 3/weather_location_combine.csv')
df
# Out:
#         Unnamed: 0  Year  Month  Day  Hour  Minute  Temperature  Clearsky DHI  \
# 0                0  2020      1    1     0       0         -2.9             0
# 1                1  2020      1    1     0      30         -3.0             0
# 2                2  2020      1    1     1       0         -3.1             0
# 3                3  2020      1    1     1      30         -3.1             0
# 4                4  2020      1    1     2       0         -3.1             0
# ...            ...   ...    ...  ...   ...     ...          ...           ...
# 788395       17515  2016     12   31    21      30         -2.0             0
# 788396       17516  2016     12   31    22       0         -2.0             0
# 788397       17517  2016     12   31    22      30         -2.0             0
# 788398       17518  2016     12   31    23       0         -2.0             0
# 788399       17519  2016     12   31    23      30         -2.0             0
#
#         Clearsky DNI  Clearsky GHI  ...  Solar Zenith Angle  Surface Albedo  \
# 0                  0             0  ...              161.09            0.11
# 1                  0             0  ...              159.68            0.11
# 2                  0             0  ...              156.62            0.11
# 3                  0             0  ...              152.47            0.11
# 4                  0             0  ...              147.67            0.11
# ...              ...           ...  ...                 ...             ...
# 788395             0             0  ...              139.45            0.07
# 788396             0             0  ...              143.95            0.07
# 788397             0             0  ...              148.03            0.07
# 788398             0             0  ...              151.47            0.07
# 788399             0             0  ...              153.99            0.07
#
#         Pressure  Precipitable Water  Wind Direction  Wind Speed  Location ID  \
# 0            987               0.400           277.0         5.4       903523
# 1            987               0.400           275.0         5.2       903523
# 2            987               0.400           273.0         5.0       903523
# 3            987               0.400           270.0         4.9       903523
# 4            987               0.400           267.0         4.8       903523
# ...          ...                 ...             ...         ...          ...
# 788395      1020               0.391            90.0         0.3       241108
# 788396      1020               0.392           122.1         0.4       241108
# 788397      1020               0.393           122.1         0.4       241108
# 788398      1020               0.395           144.7         0.4       241108
# 788399      1020               0.396           144.7         0.3       241108
#
#         Latitude  Longitude  Elevation
# 0          41.89     -87.62        179
# 1          41.89     -87.62        179
# 2          41.89     -87.62        179
# 3          41.89     -87.62        179
# 4          41.89     -87.62        179
# ...          ...        ...        ...
# 788395     47.61    -122.34         49
# 788396     47.61    -122.34         49
# 788397     47.61    -122.34         49
# 788398     47.61    -122.34         49
# 788399     47.61    -122.34         49
#
# [788400 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'Temperature',
#        'Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI', 'Cloud Type',
#        'Dew Point', 'DHI', 'DNI', 'GHI', 'Relative Humidity',
#        'Solar Zenith Angle', 'Surface Albedo', 'Pressure',
#        'Precipitable Water', 'Wind Direction', 'Wind Speed', 'Location ID',
#        'Latitude', 'Longitude', 'Elevation'],
#       dtype='object')

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
null_rows = df[df.isna().any(axis=1)]
null_rows
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, Hour, Minute, Temperature, Clearsky DHI, Clearsky DNI, Clearsky GHI, Cloud Type, Dew Point, DHI, DNI, GHI, Relative Humidity, Solar Zenith Angle, Surface Albedo, Pressure, Precipitable Water, Wind Direction, Wind Speed, Location ID, Latitude, Longitude, Elevation]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Hour                  0
# Minute                0
# Temperature           0
# Clearsky DHI          0
# Clearsky DNI          0
# Clearsky GHI          0
# Cloud Type            0
# Dew Point             0
# DHI                   0
# DNI                   0
# GHI                   0
# Relative Humidity     0
# Solar Zenith Angle    0
# Surface Albedo        0
# Pressure              0
# Precipitable Water    0
# Wind Direction        0
# Wind Speed            0
# Location ID           0
# Latitude              0
# Longitude             0
# Elevation             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Hour                  0
# Minute                0
# Temperature           0
# Clearsky DHI          0
# Clearsky DNI          0
# Clearsky GHI          0
# Cloud Type            0
# Dew Point             0
# DHI                   0
# DNI                   0
# GHI                   0
# Relative Humidity     0
# Solar Zenith Angle    0
# Surface Albedo        0
# Pressure              0
# Precipitable Water    0
# Wind Direction        0
# Wind Speed            0
# Location ID           0
# Latitude              0
# Longitude             0
# Elevation             0
# dtype: int64

# %%
#df.head

# %%
target = df['GHI']

# %%
target.describe()
# Out:
# count    788400.000000
# mean        174.068565
# std         261.634780
# min           0.000000
# 25%           0.000000
# 50%           3.000000
# 75%         286.000000
# max        1069.000000
# Name: GHI, dtype: float64

# %%
features = df.drop('GHI', axis = 1)

# %%
#features.head

# %%
print("Features Shape",features.shape)
print("Target Shape",target.shape)
# Out:
# Features Shape (788400, 24)
# Target Shape (788400,)

# %% [markdown]
# ## Correlation

# %%
import matplotlib.pyplot as plt

def show_scatter_plot(title, 
                      x_label, y_label, 
                      x_values, y_values):
    """
    @param title the chart title.
    @param x_label the x-axis label.
    @param y_label the y-axis label.
    @param x_values the independent x values to plot.
    @param y_values the dependent y values to plot.
    """
    plt.scatter(x_values, y_values)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

# %%
import math
import numpy as np

def calculate_r(x_values, y_values):
    """
    Calculate the correlation coefficient.
    @param x_values the x values.
    @param y_values the y values.
    @return the correlation coefficient.
    """
    x = np.array(x_values)
    y = np.array(y_values)
    
    n = len(x)
    sum_x  = np.sum(x)
    sum_y  = np.sum(y)
    sum_xx = np.sum(x*x)
    sum_yy = np.sum(y*y)
    sum_xy = np.sum(x*y)
    
    numerator = sum_xy - (sum_x*sum_y)/n
    denominator = math.sqrt(sum_xx - (sum_x*sum_x)/n)*math.sqrt(sum_yy - (sum_y*sum_y)/n)
    
    r = (numerator/denominator) * 100
    return r

# %%
r = calculate_r(df["Solar Zenith Angle"], target)
print("Correlation between GHI and Solar Zenith Angle", f'R2 = {r:.3f}')
# Out:
# Correlation between GHI and Solar Zenith Angle R2 = -79.289

# %%
r = calculate_r(df["Temperature"], target)
print("Correlation between GHI and Temperature", f'R2 = {r:.3f}')
# Out:
# Correlation between GHI and Temperature R2 = 42.458

# %%
r = calculate_r(df["Pressure"], target)
print("Correlation between GHI and Pressure", f'R2 = {r:.3f}')
# Out:
# Correlation between GHI and Pressure R2 = -2.202

# %%
show_scatter_plot('Scatterplot','Temperature','GHI',df["Temperature"],target)

# %%
show_scatter_plot('Scatterplot','Solar Zenith Angle','GHI',df["Solar Zenith Angle"],target)

# %%
show_scatter_plot('Scatterplot','Dew Point','GHI',df["Dew Point"],target)

# %%
df['Datetime'] = df['Year'].map(str) + '-' + df['Month'].map(str).str.zfill(2) + '-' + df['Day'].map(str).str.zfill(2)+' ' + df['Hour'].map(str).str.zfill(2)+':' + df['Hour'].map(str).str.zfill(2)+":00"
print (df)
df = df.drop(['Year', 'Month', 'Day','Hour','Minute'], axis = 1)

df = df.drop(["Latitude","Longitude"], axis = 1)
df.corr(method ='pearson')

#correlation = df["GHI"].corr(df["Temperature"])
#correlation 
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None, low=0.75, high=1.0)
# Out:
#         Year  Month  Day  Hour  Minute  Temperature  Clearsky DHI  \
# 0       2020      1    1     0       0         -2.9             0
# 1       2020      1    1     0      30         -3.0             0
# 2       2020      1    1     1       0         -3.1             0
# 3       2020      1    1     1      30         -3.1             0
# 4       2020      1    1     2       0         -3.1             0
# ...      ...    ...  ...   ...     ...          ...           ...
# 788395  2016     12   31    21      30         -2.0             0
# 788396  2016     12   31    22       0         -2.0             0
# 788397  2016     12   31    22      30         -2.0             0
# 788398  2016     12   31    23       0         -2.0             0
# 788399  2016     12   31    23      30         -2.0             0
#
#         Clearsky DNI  Clearsky GHI  Cloud Type  ...  Surface Albedo  Pressure  \
# 0                  0             0           0  ...            0.11       987
# 1                  0             0           4  ...            0.11       987
# 2                  0             0           4  ...            0.11       987
# 3                  0             0           4  ...            0.11       987
# 4                  0             0           4  ...            0.11       987
# ...              ...           ...         ...  ...             ...       ...
# 788395             0             0           0  ...            0.07      1020
# 788396             0             0           1  ...            0.07      1020
# 788397             0             0           0  ...            0.07      1020
# 788398             0             0           1  ...            0.07      1020
# 788399             0             0           1  ...            0.07      1020
#
#         Precipitable Water  Wind Direction  Wind Speed  Location ID  Latitude  \
# 0                    0.400           277.0         5.4       903523     41.89
# 1                    0.400           275.0         5.2       903523     41.89
# 2                    0.400           273.0         5.0       903523     41.89
# 3                    0.400           270.0         4.9       903523     41.89
# 4                    0.400           267.0         4.8       903523     41.89
# ...                    ...             ...         ...          ...       ...
# 788395               0.391            90.0         0.3       241108     47.61
# 788396               0.392           122.1         0.4       241108     47.61
# 788397               0.393           122.1         0.4       241108     47.61
# 788398               0.395           144.7         0.4       241108     47.61
# 788399               0.396           144.7         0.3       241108     47.61
#
#         Longitude  Elevation             Datetime
# 0          -87.62        179  2020-01-01 00:00:00
# 1          -87.62        179  2020-01-01 00:00:00
# 2          -87.62        179  2020-01-01 01:01:00
# 3          -87.62        179  2020-01-01 01:01:00
# 4          -87.62        179  2020-01-01 02:02:00
# ...           ...        ...                  ...
# 788395    -122.34         49  2016-12-31 21:21:00
# 788396    -122.34         49  2016-12-31 22:22:00
# 788397    -122.34         49  2016-12-31 22:22:00
# 788398    -122.34         49  2016-12-31 23:23:00
# 788399    -122.34         49  2016-12-31 23:23:00
#
# [788400 rows x 26 columns]
# <style type="text/css">
# #T_c432c_row0_col0, #T_c432c_row1_col1, #T_c432c_row2_col2, #T_c432c_row3_col3, #T_c432c_row4_col4, #T_c432c_row5_col5, #T_c432c_row6_col6, #T_c432c_row7_col7, #T_c432c_row8_col8, #T_c432c_row9_col9, #T_c432c_row10_col10, #T_c432c_row11_col11, #T_c432c_row12_col12, #T_c432c_row13_col13, #T_c432c_row14_col14, #T_c432c_row15_col15, #T_c432c_row16_col16, #T_c432c_row17_col17 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c432c_row0_col1, #T_c432c_row1_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c432c_row0_col2, #T_c432c_row0_col7, #T_c432c_row2_col0, #T_c432c_row7_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c432c_row0_col3, #T_c432c_row0_col8, #T_c432c_row3_col0, #T_c432c_row8_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c432c_row0_col4, #T_c432c_row4_col0, #T_c432c_row13_col14, #T_c432c_row14_col13 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c432c_row0_col5, #T_c432c_row5_col0, #T_c432c_row5_col13, #T_c432c_row7_col8, #T_c432c_row8_col7, #T_c432c_row13_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_c432c_row0_col6, #T_c432c_row6_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c432c_row0_col9, #T_c432c_row9_col0, #T_c432c_row13_col17, #T_c432c_row17_col13 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c432c_row0_col10, #T_c432c_row10_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c432c_row0_col11, #T_c432c_row5_col11, #T_c432c_row9_col17, #T_c432c_row11_col0, #T_c432c_row11_col5, #T_c432c_row17_col9 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c432c_row0_col12, #T_c432c_row4_col6, #T_c432c_row4_col15, #T_c432c_row6_col4, #T_c432c_row8_col13, #T_c432c_row11_col17, #T_c432c_row12_col0, #T_c432c_row13_col8, #T_c432c_row15_col4, #T_c432c_row17_col11 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_c432c_row0_col13, #T_c432c_row13_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_c432c_row0_col14, #T_c432c_row14_col0, #T_c432c_row16_col17, #T_c432c_row17_col16 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c432c_row0_col15, #T_c432c_row1_col12, #T_c432c_row2_col13, #T_c432c_row3_col16, #T_c432c_row5_col7, #T_c432c_row7_col5, #T_c432c_row8_col15, #T_c432c_row8_col17, #T_c432c_row10_col14, #T_c432c_row12_col1, #T_c432c_row13_col2, #T_c432c_row14_col10, #T_c432c_row15_col0, #T_c432c_row15_col8, #T_c432c_row16_col3, #T_c432c_row17_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_c432c_row0_col16, #T_c432c_row1_col16, #T_c432c_row2_col5, #T_c432c_row2_col15, #T_c432c_row2_col17, #T_c432c_row3_col15, #T_c432c_row5_col2, #T_c432c_row6_col15, #T_c432c_row6_col16, #T_c432c_row7_col17, #T_c432c_row9_col11, #T_c432c_row11_col9, #T_c432c_row11_col14, #T_c432c_row11_col15, #T_c432c_row13_col15, #T_c432c_row14_col11, #T_c432c_row15_col2, #T_c432c_row15_col3, #T_c432c_row15_col6, #T_c432c_row15_col11, #T_c432c_row15_col13, #T_c432c_row15_col16, #T_c432c_row16_col0, #T_c432c_row16_col1, #T_c432c_row16_col6, #T_c432c_row16_col15, #T_c432c_row17_col2, #T_c432c_row17_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c432c_row0_col17, #T_c432c_row2_col4, #T_c432c_row3_col11, #T_c432c_row4_col2, #T_c432c_row4_col5, #T_c432c_row4_col14, #T_c432c_row5_col4, #T_c432c_row6_col11, #T_c432c_row8_col11, #T_c432c_row9_col14, #T_c432c_row11_col3, #T_c432c_row11_col6, #T_c432c_row11_col8, #T_c432c_row11_col12, #T_c432c_row12_col11, #T_c432c_row14_col4, #T_c432c_row14_col9, #T_c432c_row17_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c432c_row1_col2, #T_c432c_row2_col1, #T_c432c_row3_col6, #T_c432c_row6_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_c432c_row1_col3, #T_c432c_row3_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_c432c_row1_col4, #T_c432c_row2_col16, #T_c432c_row3_col12, #T_c432c_row3_col14, #T_c432c_row4_col1, #T_c432c_row4_col12, #T_c432c_row4_col17, #T_c432c_row6_col17, #T_c432c_row8_col12, #T_c432c_row8_col16, #T_c432c_row12_col3, #T_c432c_row12_col4, #T_c432c_row12_col8, #T_c432c_row12_col15, #T_c432c_row14_col3, #T_c432c_row15_col12, #T_c432c_row15_col17, #T_c432c_row16_col2, #T_c432c_row16_col8, #T_c432c_row17_col4, #T_c432c_row17_col6, #T_c432c_row17_col15 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c432c_row1_col5, #T_c432c_row5_col1, #T_c432c_row6_col13, #T_c432c_row9_col13, #T_c432c_row13_col6, #T_c432c_row13_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_c432c_row1_col6, #T_c432c_row2_col8, #T_c432c_row6_col1, #T_c432c_row8_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_c432c_row1_col7, #T_c432c_row7_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_c432c_row1_col8, #T_c432c_row2_col6, #T_c432c_row2_col7, #T_c432c_row6_col2, #T_c432c_row7_col2, #T_c432c_row8_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_c432c_row1_col9, #T_c432c_row4_col7, #T_c432c_row7_col4, #T_c432c_row9_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c432c_row1_col10, #T_c432c_row10_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_c432c_row1_col11, #T_c432c_row3_col4, #T_c432c_row4_col3, #T_c432c_row11_col1, #T_c432c_row12_col14, #T_c432c_row14_col12, #T_c432c_row14_col15, #T_c432c_row15_col14 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c432c_row1_col13, #T_c432c_row5_col9, #T_c432c_row9_col5, #T_c432c_row12_col13, #T_c432c_row13_col1, #T_c432c_row13_col12 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c432c_row1_col14, #T_c432c_row1_col17, #T_c432c_row2_col12, #T_c432c_row6_col14, #T_c432c_row7_col12, #T_c432c_row7_col16, #T_c432c_row9_col15, #T_c432c_row10_col15, #T_c432c_row12_col2, #T_c432c_row12_col7, #T_c432c_row14_col1, #T_c432c_row14_col6, #T_c432c_row15_col9, #T_c432c_row15_col10, #T_c432c_row16_col7, #T_c432c_row17_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_c432c_row1_col15, #T_c432c_row4_col10, #T_c432c_row4_col13, #T_c432c_row7_col14, #T_c432c_row10_col4, #T_c432c_row13_col4, #T_c432c_row14_col7, #T_c432c_row14_col17, #T_c432c_row15_col1, #T_c432c_row17_col14 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_c432c_row2_col3, #T_c432c_row3_col2, #T_c432c_row3_col8, #T_c432c_row8_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c432c_row2_col9, #T_c432c_row3_col9, #T_c432c_row9_col2, #T_c432c_row9_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_c432c_row2_col10, #T_c432c_row3_col10, #T_c432c_row10_col2, #T_c432c_row10_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_c432c_row2_col11, #T_c432c_row7_col11, #T_c432c_row7_col13, #T_c432c_row11_col2, #T_c432c_row11_col7, #T_c432c_row13_col7, #T_c432c_row14_col16, #T_c432c_row16_col14 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_c432c_row2_col14, #T_c432c_row3_col17, #T_c432c_row4_col16, #T_c432c_row5_col15, #T_c432c_row6_col12, #T_c432c_row7_col15, #T_c432c_row8_col14, #T_c432c_row10_col12, #T_c432c_row10_col16, #T_c432c_row10_col17, #T_c432c_row12_col6, #T_c432c_row12_col10, #T_c432c_row14_col2, #T_c432c_row14_col8, #T_c432c_row15_col5, #T_c432c_row15_col7, #T_c432c_row16_col4, #T_c432c_row16_col10, #T_c432c_row17_col3, #T_c432c_row17_col10 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c432c_row3_col5, #T_c432c_row5_col3, #T_c432c_row5_col16, #T_c432c_row16_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_c432c_row3_col7, #T_c432c_row6_col8, #T_c432c_row7_col3, #T_c432c_row8_col6 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_c432c_row3_col13, #T_c432c_row4_col11, #T_c432c_row5_col8, #T_c432c_row8_col5, #T_c432c_row9_col16, #T_c432c_row11_col4, #T_c432c_row12_col16, #T_c432c_row13_col3, #T_c432c_row16_col9, #T_c432c_row16_col12 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c432c_row4_col8, #T_c432c_row8_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c432c_row4_col9, #T_c432c_row9_col4, #T_c432c_row13_col16, #T_c432c_row16_col13 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c432c_row5_col6, #T_c432c_row6_col5 {
#   background-co

# %% [markdown]
# # Ranbdom Forest for feature selection

# %%
#https://www.yourdatateacher.com/2021/10/11/feature-selection-with-random-forest/#:~:text=Random%20Forest%20is%20a%20very,a%20Recursive%20Feature%20Elimination%20procedure.
import numpy as np
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV
import matplotlib.pyplot as plt

# %%
X_train, X_test, y_train, y_test = train_test_split(df , target, test_size=0.33, random_state=42)

# %%
print("x_train shape",X_train.shape)
print("x_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_text shape",y_test.shape)
# Out:
# x_train shape (528228, 19)
# x_test shape (260172, 19)
# y_train shape (528228,)
# y_text shape (260172,)

# %% [markdown]
# # XGBoost

# %%
from datetime import datetime

# %%
df
# Out:
#         Temperature  Clearsky DHI  Clearsky DNI  Clearsky GHI  Cloud Type  \
# 0              -2.9             0             0             0           0
# 1              -3.0             0             0             0           4
# 2              -3.1             0             0             0           4
# 3              -3.1             0             0             0           4
# 4              -3.1             0             0             0           4
# ...             ...           ...           ...           ...         ...
# 788395         -2.0             0             0             0           0
# 788396         -2.0             0             0             0           1
# 788397         -2.0             0             0             0           0
# 788398         -2.0             0             0             0           1
# 788399         -2.0             0             0             0           1
#
#         Dew Point  DHI  DNI  GHI  Relative Humidity  Solar Zenith Angle  \
# 0            -4.6    0    0    0              88.28              161.09
# 1            -4.6    0    0    0              88.94              159.68
# 2            -4.7    0    0    0              88.51              156.62
# 3            -4.7    0    0    0              88.51              152.47
# 4            -4.8    0    0    0              87.92              147.67
# ...           ...  ...  ...  ...                ...                 ...
# 788395       -7.0    0    0    0              68.00              139.45
# 788396       -7.0    0    0    0              66.53              143.95
# 788397       -7.0    0    0    0              66.52              148.03
# 788398       -7.0    0    0    0              65.47              151.47
# 788399       -7.0    0    0    0              65.46              153.99
#
#         Surface Albedo  Pressure  Precipitable Water  Wind Direction  \
# 0                 0.11       987               0.400           277.0
# 1                 0.11       987               0.400           275.0
# 2                 0.11       987               0.400           273.0
# 3                 0.11       987               0.400           270.0
# 4                 0.11       987               0.400           267.0
# ...                ...       ...                 ...             ...
# 788395            0.07      1020               0.391            90.0
# 788396            0.07      1020               0.392           122.1
# 788397            0.07      1020               0.393           122.1
# 788398            0.07      1020               0.395           144.7
# 788399            0.07      1020               0.396           144.7
#
#         Wind Speed  Location ID  Elevation             Datetime
# 0              5.4       903523        179  2020-01-01 00:00:00
# 1              5.2       903523        179  2020-01-01 00:00:00
# 2              5.0       903523        179  2020-01-01 01:01:00
# 3              4.9       903523        179  2020-01-01 01:01:00
# 4              4.8       903523        179  2020-01-01 02:02:00
# ...            ...          ...        ...                  ...
# 788395         0.3       241108         49  2016-12-31 21:21:00
# 788396         0.4       241108         49  2016-12-31 22:22:00
# 788397         0.4       241108         49  2016-12-31 22:22:00
# 788398         0.4       241108         49  2016-12-31 23:23:00
# 788399         0.3       241108         49  2016-12-31 23:23:00
#
# [788400 rows x 19 columns]

# %%
df1 = df

# %%
df1.columns
# Out:
# Index(['Temperature', 'Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI',
#        'Cloud Type', 'Dew Point', 'DHI', 'DNI', 'GHI', 'Relative Humidity',
#        'Solar Zenith Angle', 'Surface Albedo', 'Pressure',
#        'Precipitable Water', 'Wind Direction', 'Wind Speed', 'Location ID',
#        'Elevation', 'Datetime'],
#       dtype='object')

# %%
#df1 = df1.drop("Unnamed: 0", axis = 1)

# %%
df1.head()
# Out:
#    Temperature  Clearsky DHI  Clearsky DNI  Clearsky GHI  Cloud Type  \
# 0         -2.9             0             0             0           0
# 1         -3.0             0             0             0           4
# 2         -3.1             0             0             0           4
# 3         -3.1             0             0             0           4
# 4         -3.1             0             0             0           4
#
#    Dew Point  DHI  DNI  GHI  Relative Humidity  Solar Zenith Angle  \
# 0       -4.6    0    0    0              88.28              161.09
# 1       -4.6    0    0    0              88.94              159.68
# 2       -4.7    0    0    0              88.51              156.62
# 3       -4.7    0    0    0              88.51              152.47
# 4       -4.8    0    0    0              87.92              147.67
#
#    Surface Albedo  Pressure  Precipitable Water  Wind Direction  Wind Speed  \
# 0            0.11       987                 0.4           277.0         5.4
# 1            0.11       987                 0.4           275.0         5.2
# 2            0.11       987                 0.4           273.0         5.0
# 3            0.11       987                 0.4           270.0         4.9
# 4            0.11       987                 0.4           267.0         4.8
#
#    Location ID  Elevation             Datetime
# 0       903523        179  2020-01-01 00:00:00
# 1       903523        179  2020-01-01 00:00:00
# 2       903523        179  2020-01-01 01:01:00
# 3       903523        179  2020-01-01 01:01:00
# 4       903523        179  2020-01-01 02:02:00

# %%
df1['Datetime'] = pd.to_datetime(df1['Datetime'])

# %%
#https://towardsdatascience.com/time-series-analysis-using-pandas-in-python-f726d87a97d8
df1.dtypes
# Out:
# Temperature                  float64
# Clearsky DHI                   int64
# Clearsky DNI                   int64
# Clearsky GHI                   int64
# Cloud Type                     int64
# Dew Point                    float64
# DHI                            int64
# DNI                            int64
# GHI                            int64
# Relative Humidity            float64
# Solar Zenith Angle           float64
# Surface Albedo               float64
# Pressure                       int64
# Precipitable Water           float64
# Wind Direction               float64
# Wind Speed                   float64
# Location ID                    int64
# Elevation                      int64
# Datetime              datetime64[ns]
# dtype: object

# %%
data = df1.set_index('Datetime')
data
# Out:
#                      Temperature  Clearsky DHI  Clearsky DNI  Clearsky GHI  \
# Datetime
# 2020-01-01 00:00:00         -2.9             0             0             0
# 2020-01-01 00:00:00         -3.0             0             0             0
# 2020-01-01 01:01:00         -3.1             0             0             0
# 2020-01-01 01:01:00         -3.1             0             0             0
# 2020-01-01 02:02:00         -3.1             0             0             0
# ...                          ...           ...           ...           ...
# 2016-12-31 21:21:00         -2.0             0             0             0
# 2016-12-31 22:22:00         -2.0             0             0             0
# 2016-12-31 22:22:00         -2.0             0             0             0
# 2016-12-31 23:23:00         -2.0             0             0             0
# 2016-12-31 23:23:00         -2.0             0             0             0
#
#                      Cloud Type  Dew Point  DHI  DNI  GHI  Relative Humidity  \
# Datetime
# 2020-01-01 00:00:00           0       -4.6    0    0    0              88.28
# 2020-01-01 00:00:00           4       -4.6    0    0    0              88.94
# 2020-01-01 01:01:00           4       -4.7    0    0    0              88.51
# 2020-01-01 01:01:00           4       -4.7    0    0    0              88.51
# 2020-01-01 02:02:00           4       -4.8    0    0    0              87.92
# ...                         ...        ...  ...  ...  ...                ...
# 2016-12-31 21:21:00           0       -7.0    0    0    0              68.00
# 2016-12-31 22:22:00           1       -7.0    0    0    0              66.53
# 2016-12-31 22:22:00           0       -7.0    0    0    0              66.52
# 2016-12-31 23:23:00           1       -7.0    0    0    0              65.47
# 2016-12-31 23:23:00           1       -7.0    0    0    0              65.46
#
#                      Solar Zenith Angle  Surface Albedo  Pressure  \
# Datetime
# 2020-01-01 00:00:00              161.09            0.11       987
# 2020-01-01 00:00:00              159.68            0.11       987
# 2020-01-01 01:01:00              156.62            0.11       987
# 2020-01-01 01:01:00              152.47            0.11       987
# 2020-01-01 02:02:00              147.67            0.11       987
# ...                                 ...             ...       ...
# 2016-12-31 21:21:00              139.45            0.07      1020
# 2016-12-31 22:22:00              143.95            0.07      1020
# 2016-12-31 22:22:00              148.03            0.07      1020
# 2016-12-31 23:23:00              151.47            0.07      1020
# 2016-12-31 23:23:00              153.99            0.07      1020
#
#                      Precipitable Water  Wind Direction  Wind Speed  \
# Datetime
# 2020-01-01 00:00:00               0.400           277.0         5.4
# 2020-01-01 00:00:00               0.400           275.0         5.2
# 2020-01-01 01:01:00               0.400           273.0         5.0
# 2020-01-01 01:01:00               0.400           270.0         4.9
# 2020-01-01 02:02:00               0.400           267.0         4.8
# ...                                 ...             ...         ...
# 2016-12-31 21:21:00               0.391            90.0         0.3
# 2016-12-31 22:22:00               0.392           122.1         0.4
# 2016-12-31 22:22:00               0.393           122.1         0.4
# 2016-12-31 23:23:00               0.395           144.7         0.4
# 2016-12-31 23:23:00               0.396           144.7         0.3
#
#                      Location ID  Elevation
# Datetime
# 2020-01-01 00:00:00       903523        179
# 2020-01-01 00:00:00       903523        179
# 2020-01-01 01:01:00       903523        179
# 2020-01-01 01:01:00       903523        179
# 2020-01-01 02:02:00       903523        179
# ...                          ...        ...
# 2016-12-31 21:21:00       241108         49
# 2016-12-31 22:22:00       241108         49
# 2016-12-31 22:22:00       241108         49
# 2016-12-31 23:23:00       241108         49
# 2016-12-31 23:23:00       241108         49
#
# [788400 rows x 18 columns]

# %%
data.index
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:00:00',
#                '2020-01-01 01:01:00', '2020-01-01 01:01:00',
#                '2020-01-01 02:02:00', '2020-01-01 02:02:00',
#                '2020-01-01 03:03:00', '2020-01-01 03:03:00',
#                '2020-01-01 04:04:00', '2020-01-01 04:04:00',
#                ...
#                '2016-12-31 19:19:00', '2016-12-31 19:19:00',
#                '2016-12-31 20:20:00', '2016-12-31 20:20:00',
#                '2016-12-31 21:21:00', '2016-12-31 21:21:00',
#                '2016-12-31 22:22:00', '2016-12-31 22:22:00',
#                '2016-12-31 23:23:00', '2016-12-31 23:23:00'],
#               dtype='datetime64[ns]', name='Datetime', length=788400, freq=None)

# %%
#We can set frequency Available frequencies in pandas include hourly (‘H’), 
#calendar daily (‘D’), business daily (‘B’), weekly (‘W’), monthly (‘M’), 
#quarterly (‘Q’), annual (‘A’), and many others
data_freq = data.asfreq('D')
data_freq
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-b8fcc89d78f1> in <module>
#       2 #calendar daily (‘D’), business daily (‘B’), weekly (‘W’), monthly (‘M’),
#       3 #quarterly (‘Q’), annual (‘A’), and many others
# ----> 4 data_freq = data.asfreq('D')
#       5 data_freq
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in asfreq(self, freq, method, how, normalize, fill_value)
#   10324         fill_value=None,
#   10325     ) -> DataFrame:
# > 10326         return super().asfreq(
#   10327             freq=freq,
#   10328             method=method,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in asfreq(self, freq, method, how, normalize, fill_value)
#    7560         from pandas.core.resample import asfreq
#    7561
# -> 7562         return asfreq(
#    7563             self,
#    7564             freq,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/resample.py in asfreq(obj, freq, method, how, normalize, fill_value)
#    2049         dti = date_range(obj.index.min(), obj.index.max(), freq=freq)
#    2050         dti.name = obj.index.name
# -> 2051         new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    2052         if normalize:
#    2053             new_obj.index = new_obj.index.normalize()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4770         kwargs.pop("axis", None)
#    4771         kwargs.pop("labels", None)
# -> 4772         return super().reindex(**kwargs)
#    4773
#    4774     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4595         index = axes["index"]
#    4596         if index is not None:
# -> 4597             frame = frame._reindex_index(
#    4598                 index, method, copy, level, fill_value, limit, tolerance
#    4599             )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4614             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4615         )
# -> 4616         return self._reindex_with_indexers(
#    4617             {0: [new_index, indexer]},
#    4618             copy=copy,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
data_columns = ['GHI', 'Dew Point','Solar Zenith Angle','Surface Albedo','Precipitable Water','Relative Humidity','Temperature','Wind Speed']
data_weekly_mean = data[data_columns].resample('W').mean() # W stands for weekly
data_weekly_mean
# Out:
#                   GHI  Dew Point  Solar Zenith Angle  Surface Albedo  \
# Datetime
# 2016-01-03  80.757716  -1.300154          107.833380        0.527106
# 2016-01-10  72.471561   0.054233          107.420185        0.449219
# 2016-01-17  79.023148  -1.317130          106.623436        0.513517
# 2016-01-24  88.423942  -1.437500          105.568545        0.447476
# 2016-01-31  94.404101   1.826720          104.274286        0.403997
# ...               ...        ...                 ...             ...
# 2020-12-06  83.881283   0.226984          107.290423        0.202672
# 2020-12-13  73.293651   1.188624          107.851749        0.286792
# 2020-12-20  71.775132  -0.494709          108.140470        0.353638
# 2020-12-27  80.708003  -0.157077          108.147424        0.330714
# 2021-01-03  65.837963   0.194329          107.967564        0.354954
#
#             Precipitable Water  Relative Humidity  Temperature  Wind Speed
# Datetime
# 2016-01-03            1.104284          80.793202     2.481481    3.008410
# 2016-01-10            1.316042          86.708581     2.786706    3.138294
# 2016-01-17            1.221095          82.906253     2.054894    3.098512
# 2016-01-24            1.074451          82.163118     2.065476    2.844048
# 2016-01-31            1.298128          84.148439     5.223876    2.959127
# ...                        ...                ...          ...         ...
# 2020-12-06            1.119312          73.019563     5.349603    2.717460
# 2020-12-13            1.171825          76.520999     5.758003    2.601653
# 2020-12-20            1.142460          76.996485     3.466799    2.670866
# 2020-12-27            1.066733          75.187292     4.460119    3.494511
# 2021-01-03            1.196007          78.786487     3.858507    3.269907
#
# [262 rows x 8 columns]

# %%
data_monthly_max = data[data_columns].resample('M').max() # W stands for weekly
data_monthly_max
# Out:
#              GHI  Dew Point  Solar Zenith Angle  Surface Albedo  \
# Datetime
# 2016-01-31   798       23.0              176.94           0.866
# 2016-02-29   917       23.0              171.43           0.866
# 2016-03-31   974       24.0              161.63           0.866
# 2016-04-30  1025       24.0              149.48           0.866
# 2016-05-31  1069       25.0              138.90           0.866
# 2016-06-30  1058       27.0              132.03           0.173
# 2016-07-31  1028       27.0              136.07           0.177
# 2016-08-31  1002       27.0              145.68           0.176
# 2016-09-30   956       27.0              157.05           0.173
# 2016-10-31   877       26.0              168.42           0.866
# 2016-11-30   796       23.0              175.39           0.866
# 2016-12-31   711       24.0              176.95           0.866
# 2017-01-31   790       24.0              176.92           0.866
# 2017-02-28   881       23.0              171.21           0.866
# 2017-03-31   991       23.0              161.72           0.866
# 2017-04-30  1046       24.0              149.58           0.866
# 2017-05-31  1056       26.0              138.98           0.866
# 2017-06-30  1060       26.0              132.06           0.173
# 2017-07-31  1038       26.0              136.01           0.177
# 2017-08-31   991       26.0              145.59           0.176
# 2017-09-30   947       27.0              156.95           0.173
# 2017-10-31   865       26.0              168.34           0.866
# 2017-11-30   795       24.0              175.37           0.866
# 2017-12-31   733       24.0              176.95           0.866
# 2018-01-31   767       22.9              176.94           0.870
# 2018-02-28   864       22.5              171.29           0.870
# 2018-03-31   986       23.3              161.83           0.870
# 2018-04-30  1044       24.2              149.69           0.870
# 2018-05-31  1032       25.8              139.07           0.170
# 2018-06-30  1066       26.3              132.12           0.170
# 2018-07-31  1037       26.6              135.97           0.180
# 2018-08-31  1009       26.1              145.52           0.180
# 2018-09-30   944       25.8              156.87           0.180
# 2018-10-31   881       26.6              168.28           0.870
# 2018-11-30   759       24.7              175.35           0.870
# 2018-12-31   695       24.1              176.97           0.870
# 2019-01-31   799       22.9              176.95           0.870
# 2019-02-28   886       23.8              171.36           0.870
# 2019-03-31   997       22.7              161.92           0.870
# 2019-04-30  1041       24.7              149.78           0.870
# 2019-05-31  1045       26.2              139.14           0.870
# 2019-06-30  1050       27.9              132.15           0.180
# 2019-07-31  1025       29.2              135.91           0.180
# 2019-08-31   996       26.8              145.44           0.180
# 2019-09-30   932       26.9              156.77           0.180
# 2019-10-31   870       26.7              168.20           0.870
# 2019-11-30   774       25.3              175.33           0.870
# 2019-12-31   732       24.1              176.97           0.870
# 2020-01-31   773       23.6              176.95           0.870
# 2020-02-29   921       24.1              171.43           0.870
# 2020-03-31   978       24.0              161.63           0.870
# 2020-04-30  1040       25.9              149.49           0.870
# 2020-05-31  1048       26.2              138.91           0.870
# 2020-06-30  1050       26.8              132.05           0.180
# 2020-07-31  1050       26.9              136.09           0.180
# 2020-08-31   997       27.7              145.71           0.180
# 2020-09-30   953       26.9              157.07           0.870
# 2020-10-31   853       26.9              168.44           0.870
# 2020-11-30   741       25.7              175.41           0.870
# 2020-12-31   730       23.6              176.97           0.870
#
#             Precipitable Water  Relative Humidity  Temperature  Wind Speed
# Datetime
# 2016-01-31               5.444              100.0         27.0        14.4
# 2016-02-29               4.924              100.0         26.0        15.0
# 2016-03-31               5.066              100.0         28.0        14.2
# 2016-04-30               5.895              100.0         30.0        12.9
# 2016-05-31               6.251              100.0         32.0        11.5
# 2016-06-30               6.617              100.0         37.0         8.2
# 2016-07-31               6.828              100.0         39.0         8.7
# 2016-08-31               7.067              100.0         41.0         8.4
# 2016-09-30               6.326              100.0         38.0        12.8
# 2016-10-31               7.986              100.0         34.0        15.1
# 2016-11-30               4.842              100.0         30.0        11.7
# 2016-12-31               5.313              100.0         27.0        12.0
# 2017-01-31               4.851              100.0         26.0        14.2
# 2017-02-28               4.200              100.0         28.0        11.6
# 2017-03-31               4.387              100.0         30.0        13.9
# 2017-04-30               5.491              100.0         31.0        12.0
# 2017-05-31               5.657              100.0         35.0        12.7
# 2017-06-30               6.529              100.0         38.0        10.3
# 2017-07-31               6.678              100.0         39.0         7.8
# 2017-08-31               6.573              100.0         40.0        11.7
# 2017-09-30               7.569              100.0         44.0        24.2
# 2017-10-31               6.561              100.0         34.0        11.8
# 2017-11-30               4.881              100.0         32.0        11.8
# 2017-12-31               4.989              100.0         27.0        18.5
# 2018-01-31               4.800              100.0         24.9        18.0
# 2018-02-28               4.800              100.0         26.1        14.6
# 2018-03-31               4.600              100.0         27.7        11.9
# 2018-04-30               5.200              100.0         29.0        11.8
# 2018-05-31               6.300              100.0         37.9        13.5
# 2018-06-30               6.700              100.0         40.7         9.8
# 2018-07-31               6.300              100.0         45.4         9.2
# 2018-08-31               6.100              100.0         39.5         9.6
# 2018-09-30               6.400              100.0         37.4        11.3
# 2018-10-31               6.100              100.0         32.1        12.1
# 2018-11-30               5.800              100.0         29.6        12.8
# 2018-12-31               5.000              100.0         27.5        14.0
# 2019-01-31               4.800              100.0         26.6        17.7
# 2019-02-28               4.400              100.0         27.5        14.7
# 2019-03-31               4.800              100.0         28.5        15.2
# 2019-04-30               5.200              100.0         29.3        12.5
# 2019-05-31               6.000              100.0         30.5        11.3
# 2019-06-30               6.500              100.0         37.6         8.5
# 2019-07-31               6.500              100.0         39.0         7.1
# 2019-08-31               7.000              100.0         41.1         8.5
# 2019-09-30               6.600              100.0         40.1        11.6
# 2019-10-31               6.500              100.0         37.4        14.3
# 2019-11-30               5.500              100.0         29.6        13.7
# 2019-12-31               5.500              100.0         27.0        16.9
# 2020-01-31               5.100              100.0         26.9        13.6
# 2020-02-29               5.300              100.0         27.2        11.5
# 2020-03-31               4.900              100.0         28.6        12.1
# 2020-04-30               5.200              100.0         32.0        11.6
# 2020-05-31               6.300              100.0         36.4        13.0
# 2020-06-30               6.300              100.0         36.6        10.2
# 2020-07-31               6.700              100.0         39.7         8.1
# 2020-08-31               6.900              100.0         42.6        10.8
# 2020-09-30               7.700              100.0         44.0        14.2
# 2020-10-31               6.300              100.0         37.1        13.2
# 2020-11-30               6.600              100.0         31.9        15.4
# 2020-12-31               5.200              100.0         26.1        19.1

# %%
#To compute a 7-day rolling mean
#center = True means for the time bin, say Jan 1 to Jan 8, the rolling mean would be 
#calculated and placed next to the center of the bin i.e. Jan 4. To make it clearer
data_7d_rol = data[data_columns].rolling(window = 7, center = True).mean()
data_7d_rol
# Out:
#                      GHI  Dew Point  Solar Zenith Angle  Surface Albedo  \
# Datetime
# 2020-01-01 00:00:00  NaN        NaN                 NaN             NaN
# 2020-01-01 00:00:00  NaN        NaN                 NaN             NaN
# 2020-01-01 01:01:00  NaN        NaN                 NaN             NaN
# 2020-01-01 01:01:00  0.0  -4.714286          151.014286            0.11
# 2020-01-01 02:02:00  0.0  -4.742857          146.795714            0.11
# ...                  ...        ...                 ...             ...
# 2016-12-31 21:21:00  0.0  -6.714286          138.860000            0.07
# 2016-12-31 22:22:00  0.0  -6.857143          143.042857            0.07
# 2016-12-31 22:22:00  NaN        NaN                 NaN             NaN
# 2016-12-31 23:23:00  NaN        NaN                 NaN             NaN
# 2016-12-31 23:23:00  NaN        NaN                 NaN             NaN
#
#                      Precipitable Water  Relative Humidity  Temperature  \
# Datetime
# 2020-01-01 00:00:00                 NaN                NaN          NaN
# 2020-01-01 00:00:00                 NaN                NaN          NaN
# 2020-01-01 01:01:00                 NaN                NaN          NaN
# 2020-01-01 01:01:00            0.400000          88.504286    -3.085714
# 2020-01-01 02:02:00            0.400000          88.671429    -3.142857
# ...                                 ...                ...          ...
# 2016-12-31 21:21:00            0.392571          67.645714    -2.000000
# 2016-12-31 22:22:00            0.392857          67.068571    -2.000000
# 2016-12-31 22:22:00                 NaN                NaN          NaN
# 2016-12-31 23:23:00                 NaN                NaN          NaN
# 2016-12-31 23:23:00                 NaN                NaN          NaN
#
#                      Wind Speed
# Datetime
# 2020-01-01 00:00:00         NaN
# 2020-01-01 00:00:00         NaN
# 2020-01-01 01:01:00         NaN
# 2020-01-01 01:01:00    4.985714
# 2020-01-01 02:02:00    4.914286
# ...                         ...
# 2016-12-31 21:21:00    0.385714
# 2016-12-31 22:22:00    0.357143
# 2016-12-31 22:22:00         NaN
# 2016-12-31 23:23:00         NaN
# 2016-12-31 23:23:00         NaN
#
# [788400 rows x 8 columns]

# %%
data_365d_rol = data[data_columns].rolling(window = 365, center = True).mean()

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize = (11,4))
# plotting daily data
ax.plot(data['GHI'], marker='.', markersize=2, color='0.6',linestyle='None', label='Daily')
# plotting 7-day rolling data
ax.plot(data_7d_rol['GHI'], linewidth=2, label='7-d Rolling Mean')
# plotting annual rolling data
ax.plot(data_365d_rol['GHI'], color='0.2', linewidth=3, label='Trend (365-d Rolling Mean)')
# Beautification of plot
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('GHI (w/m2)')
ax.set_title('Trends in GHI')
# Out:
# Text(0.5, 1.0, 'Trends in GHI')
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(11,4), dpi= 80)
data['GHI'].plot(linewidth = 0.5)

# %%
#Weekly Oscilation
data.loc['2020-04': '2020-04','GHI'].plot(marker = 'o', figsize=(11, 9))

# %%
# Extract the year, month, date separately using the index set
data['Year'] = data.index.year
data['Month'] = data.index.month
data['Weekday_Name'] = data.index.weekday

# %%
import seaborn as sns
fig, axes = plt.subplots(5, 1, figsize=(30, 30), sharex=True)
for name, ax in zip(['GHI','Dew Point', 'Solar Zenith Angle','Precipitable Water','Temperature'], axes): 
    sns.boxplot(data=data, x='Month', y=name, ax=ax)
    ax.set_ylabel('')
    ax.set_title(name)
    # Keep the x-axis label for only the bottom subplot
    if ax != axes[-1]:
        ax.set_xlabel('')

# %%
import seaborn as sns
fig, axes = plt.subplots(5, 1, figsize=(40, 30), sharex=True)
for name, ax in zip(['Surface Albedo','Wind Speed','Wind Direction','Relative Humidity','Pressure'], axes):
    sns.boxplot(data=data, x='Month', y=name, ax=ax)
    ax.set_ylabel('')
    ax.set_title(name)
    # Keep the x-axis label for only the bottom subplot
    if ax != axes[-1]:
        ax.set_xlabel('')

# %% [markdown]
# Datetime              datetime64[ns]
# GHI                            int64
# Cloud Type                     int64
# Dew Point                    float64
# Solar Zenith Angle           float64
# Surface Albedo               float64
# Wind Speed                   float64
# Precipitable Water           float64
# Wind Direction                 int64
# Relative Humidity            float64
# Temperature                  float64
# Pressure                       int64
# dtype: object
