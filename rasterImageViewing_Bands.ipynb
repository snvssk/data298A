# %% [markdown]
# <a href="https://colab.research.google.com/github/snvssk/data298A/blob/saidev/rasterImageViewing_Bands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base_path = '/content/drive/Shareddrives/DATA298A/Satelite_Dataset/Spacenet2/Khartoum/'

# %%
# !pip install rasterio

# %%
import rasterio
from rasterio.plot import show
path = '/content/drive/Shareddrives/DATA298A/Satelite_Dataset/OpenCities/open_cities_ai_challenge_train_tier_1_source/open_cities_ai_challenge_train_tier_1_source_acc_d41d81/image.tif'
src = rasterio.open(path)
#src.save
#from rasterio.windows import Window
#show(src)

# %%
print("Metadata")
print(src.meta)
print("Bounds")
print(src.bounds)
# Out:
# Metadata
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 40868, 'height': 42719, 'count': 4, 'crs': CRS.from_epsg(32630), 'transform': Affine(0.05179965064903244, 0.0, 809267.1099320438,
#        0.0, -0.05180039261972288, 618981.5459276063)}
# Bounds
# BoundingBox(left=809267.1099320438, bottom=616768.6849552843, right=811384.0580547685, top=618981.5459276063)

# %%
from matplotlib import pyplot

pyplot.imshow(src.read(4)) # Band 4
#pyplot.figure(figsize=(10, 10))
pyplot.show()

# %%
path = '/content/drive/Shareddrives/DATA298A/Satelite_Dataset/OpenCities/open_cities_ai_challenge_train_tier_1_source/open_cities_ai_challenge_train_tier_1_source_acc_d41d81/image.tif'
from osgeo import gdal
import matplotlib.pyplot as plt
dataset = gdal.Open(path, gdal.GA_ReadOnly) 
# Note GetRasterBand() takes band no. starting from 1 not 0
band = dataset.GetRasterBand(1)
arr = band.ReadAsArray()
plt.imshow(arr)

# %%
from matplotlib import pyplot

pyplot.imshow(src.read(2))
#pyplot.figure(figsize=(10, 10))
pyplot.show()

# %%
from matplotlib import pyplot

pyplot.imshow(src.read(3))
#pyplot.figure(figsize=(10, 10))
pyplot.show()
